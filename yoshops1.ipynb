# %% [markdown]
# <a href="https://colab.research.google.com/github/tazalki/Data-Science-Projects-using-Python/blob/main/yoshops1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import Request
from urllib.request import urlopen

url = "https://yoshops.com/products"
r = requests.get(url)
# Out:
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()

soup = BeautifulSoup(webpage, 'html.parser')

# %%
def search(text, sub1, sub2):
    index1 = t.index(sub1)
    index2 = t.index(sub2)
    #    print(index1,sub1)
    #    print(index2,sub2)
    val = text[index1 + len(sub1) + 1: index2 - 1]
    return val


quotes = []
table = soup.find('div', class_='products')
# print(table)
lists = soup.find_all('div', class_="col-sm-3 col-xs-6")
print(lists)
# Out:
# [<div class="col-sm-3 col-xs-6">
# <div class="product">
# <a class="product-link" href="/products/reliance-jio-phone1">
# <div class="product-thumb">
# <div class="product-thumb-inner">
# <img alt="Reliance Jio Phone" src="https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1354_original/:/rs=w:600,h:600"/>
# </div>
# </div>
# <span class="product-title" href="/products/reliance-jio-phone1">Reliance Jio Phone</span>
# </a>
# <div class="product-price" data-on-sale="true"><span><span class="rupee">₹</span>1,999.00</span><span><span class="rupee">₹</span>1,499.00</span></div>
# <div class="review-wrapper">
# <div class="single-product-review">
# ...

# %%
for row in lists:
    t = str(row)
img = search(t, "src=", "/>")
